# %%
import pymongo

myclient = pymongo.MongoClient("mongodb+srv://chris:555Project2021@cluster0.kphap.mongodb.net/SearchEngine?retryWrites=true&w=majority")
mydb = myclient["SearchEngine"]
mycol = mydb["indexes"]

mydoc = mycol.find({'lemma' : { "$not": {"$regex" : ".* .*"} }})
lexicon = {}
URL_WTD = {}
num = 0
for x in mydoc:
    num += 1
    if num < 10:
        print(x)
# Out:
# {'_id': ObjectId('608ba2d1b9a90f10cf04140f'), 'lemma': '0x08', 'IDF': 4.039897721299767, 'numDocs': 5, 'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/ISO/IEC_15693', 'docObjID': ObjectId('6089195963d00e014ef892af'), 'numHits': 1, 'TF': 0.503030303030303, 'WTD': 0.0047414136659859754, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/rfc2896', 'docObjID': ObjectId('608923eb0e90df59d15071a5'), 'numHits': 1, 'TF': 0.5006906077348067, 'WTD': 0.0006915710356559714, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/opsawg-tacacs-10', 'docObjID': ObjectId('608924060e90df59d15071c1'), 'numHits': 3, 'TF': 0.5015923566878981, 'WTD': 0.002259277639509749, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/draft-ietf-quic-transport-13', 'docObjID': ObjectId('608924100e90df59d15071ca'), 'numHits': 2, 'TF': 0.500453514739229, 'WTD': 0.0004989640721065118, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/draft-wood-tsvwg-saratoga-20', 'docObjID': ObjectId('608924510e90df59d1507219'), 'numHits': 1, 'TF': 0.5005219206680585, 'WTD': 0.0005347327515273427, 'inTitle': False}]}
# {'_id': ObjectId('608ba2d14f710234c846e2b3'), 'lemma': '002f', 'IDF': 4.039897721299767, 'numDocs': 5, 'docList': [{'docURL': 'https://tools.ietf.org:443/html/rfc1700', 'docObjID': ObjectId('608924770e90df59d1507242'), 'numHits': 1, 'TF': 0.5006435006435006, 'WTD': 0.0004754336190740987, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Polychlorinated_dibenzodioxins', 'docObjID': ObjectId('6089196c63d00e014ef892e6'), 'numHits': 1, 'TF': 0.5019762845849802, 'WTD': 0.0020162847574541416, 'inTitle': False}, {'docURL': 'https://commons.wikimedia.org:443/wiki/Category:Leisure', 'docObjID': ObjectId('6089be1b965a6a6a98fa8022'), 'numHits': 1, 'TF': 0.5048076923076923, 'WTD': 0.004454177282313847, 'inTitle': False}, {'docURL': 'https://commons.wikimedia.org:443/wiki/Category:Leisure', 'docObjID': ObjectId('6089be1b965a6a6a98fa8023'), 'numHits': 1, 'TF': 0.5048076923076923, 'WTD': 0.004454177282313847, 'inTitle': False}, {'docURL': 'https://commons.wikimedia.org:443/wiki/Category:Bays', 'docObjID': ObjectId('6089b83dd00d621bf541d004'), 'numHits': 1, 'TF': 0.5052631578947369, 'WTD': 0.005242864728966902, 'inTitle': False}]}
# {'_id': ObjectId('608ba2d14f710234c846e2b4'), 'lemma': '0c', 'IDF': 3.893769685621529, 'numDocs': 7, 'docList': [{'docURL': 'https://en.wikisource.org:443/wiki/Portal:R._Shugg_%26_Co.', 'docObjID': ObjectId('60891a3204b1fc0ef4774f09'), 'numHits': 1, 'TF': 0.625, 'WTD': 0.05679618342470648, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Norway', 'docObjID': ObjectId('60891a0163d00e014ef8943b'), 'numHits': 1, 'TF': 0.5002979737783075, 'WTD': 0.0003998318820480981, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/draft-wood-tsvwg-saratoga-20', 'docObjID': ObjectId('608924510e90df59d1507219'), 'numHits': 1, 'TF': 0.5005219206680585, 'WTD': 0.0005347327515273427, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/rfc6979', 'docObjID': ObjectId('608924a90e90df59d150724f'), 'numHits': 2, 'TF': 0.5023201856148491, 'WTD': 0.0018837528354839295, 'inTitle': False}, {'docURL': 'https://en.wikibooks.org:443/wiki/Cookbook:Christmas_ham', 'docObjID': ObjectId('6089bd3d3839b3315dec1ba3'), 'numHits': 1, 'TF': 0.5131578947368421, 'WTD': 0.012544178421634482, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/rfc1028', 'docObjID': ObjectId('608924230e90df59d15071dd'), 'numHits': 2, 'TF': 0.5009225092250923, 'WTD': 0.0011763088060213185, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/rfc3977', 'docObjID': ObjectId('6089241c0e90df59d15071d7'), 'numHits': 1, 'TF': 0.5002434274586174, 'WTD': 0.0002899409773878673, 'inTitle': False}]}
# {'_id': ObjectId('608ba2d14f710234c846e2b5'), 'lemma': '0x06', 'IDF': 4.039897721299767, 'numDocs': 5, 'docList': [{'docURL': 'https://tools.ietf.org:443/html/rfc2896', 'docObjID': ObjectId('608923eb0e90df59d15071a5'), 'numHits': 3, 'TF': 0.5020718232044199, 'WTD': 0.0020747131069679143, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/draft-ietf-quic-transport-13', 'docObjID': ObjectId('608924100e90df59d15071ca'), 'numHits': 2, 'TF': 0.500453514739229, 'WTD': 0.0004989640721065118, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/opsawg-tacacs-10', 'docObjID': ObjectId('608924060e90df59d15071c1'), 'numHits': 4, 'TF': 0.5021231422505308, 'WTD': 0.003012370186012999, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/draft-wood-tsvwg-saratoga-20', 'docObjID': ObjectId('608924510e90df59d1507219'), 'numHits': 1, 'TF': 0.5005219206680585, 'WTD': 0.0005347327515273427, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/ISO/IEC_15693', 'docObjID': ObjectId('6089195963d00e014ef892af'), 'numHits': 1, 'TF': 0.503030303030303, 'WTD': 0.0047414136659859754, 'inTitle': False}]}
# {'_id': ObjectId('608ba2d14f710234c846e2b6'), 'lemma': '0x3', 'IDF': 3.960716475252142, 'numDocs': 6, 'docList': [{'docURL': 'https://tools.ietf.org:443/html/rfc7540', 'docObjID': ObjectId('6089240d0e90df59d15071c9'), 'numHits': 6, 'TF': 0.5020380434782609, 'WTD': 0.0020788751638548477, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/draft-ietf-quic-transport-13', 'docObjID': ObjectId('608924100e90df59d15071ca'), 'numHits': 3, 'TF': 0.5006802721088436, 'WTD': 0.0007484461081597677, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/rfc1002', 'docObjID': ObjectId('6089241f0e90df59d15071db'), 'numHits': 1, 'TF': 0.5009803921568627, 'WTD': 0.000840750348040633, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/rfc1002', 'docObjID': ObjectId('6089241f0e90df59d15071da'), 'numHits': 1, 'TF': 0.5009803921568627, 'WTD': 0.000840750348040633, 'inTitle': False}, {'docURL': 'http://www.brendangregg.com:80/perf.html', 'docObjID': ObjectId('60891a6a04b1fc0ef4774f6b'), 'numHits': 2, 'TF': 0.5017513134851138, 'WTD': 0.001509632178319973, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_video_game_console_palettes', 'docObjID': ObjectId('608916b3414adb5d4f9e78ad'), 'numHits': 2, 'TF': 0.5105263157894737, 'WTD': 0.009578153011637069, 'inTitle': False}]}
# {'_id': ObjectId('608ba2d1b9a90f10cf041436'), 'lemma': '106th', 'IDF': 3.8357777386438423, 'numDocs': 8, 'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Index_of_Montana-related_articles', 'docObjID': ObjectId('60891835414adb5d4f9e7bfc'), 'numHits': 1, 'TF': 0.5014285714285714, 'WTD': 0.001830933813981613, 'inTitle': False}, {'docURL': 'https://digitalalabama.com:443/alabama-civil-war/alabama-civil-war-timeline/27066', 'docObjID': ObjectId('6089b79482c133359bf950a4'), 'numHits': 4, 'TF': 0.5045045045045045, 'WTD': 0.0033688908263510378, 'inTitle': False}, {'docURL': 'https://www.cnn.com:443/2021/04/24/politics/armenian-genocide-biden-erdogan-turkey/index.html', 'docObjID': ObjectId('6089b77382c133359bf9503b'), 'numHits': 1, 'TF': 0.5053763440860215, 'WTD': 0.005578675766153785, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/2000_Major_League_Baseball_season', 'docObjID': ObjectId('6089bdb458a2d0622c5e4cef'), 'numHits': 1, 'TF': 0.5011737089201878, 'WTD': 0.0015073340649834172, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Introduction_to_the_metric_system', 'docObjID': ObjectId('608919ac63d00e014ef89384'), 'numHits': 1, 'TF': 0.5003348961821835, 'WTD': 0.00044872552065622036, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Atomic_mass_unit', 'docObjID': ObjectId('6089198d63d00e014ef89331'), 'numHits': 1, 'TF': 0.5019685039370079, 'WTD': 0.0024962661939729462, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Algeria', 'docObjID': ObjectId('60891a0963d00e014ef89448'), 'numHits': 1, 'TF': 0.5004965243296922, 'WTD': 0.0006796552923037043, 'inTitle': False}, {'docURL': 'https://en.wiktionary.org:443/wiki/Wiktionary:Tea_Room', 'docObjID': ObjectId('60891dd82ba5f05586cf82f4'), 'numHits': 1, 'TF': 0.5002304147465437, 'WTD': 0.00022294542460432718, 'inTitle': False}]}
# {'_id': ObjectId('608ba2d1b9a90f10cf041439'), 'lemma': '10th', 'IDF': 2.109458126533067, 'numDocs': 426, 'docList': [{'docURL': 'https://icd.who.int:443/browse10/2019/en', 'docObjID': ObjectId('60891e14bbc5f62504ac6dfb'), 'numHits': 1, 'TF': 0.5098039215686274, 'WTD': 0.01188372799684306, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Category:Webarchive_template_archiveis_links', 'docObjID': ObjectId('608922e51423671fb0475947'), 'numHits': 1, 'TF': 0.5151515151515151, 'WTD': 0.009913144821476802, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Category:Use_dmy_dates_from_June_2020', 'docObjID': ObjectId('608922e61423671fb0475949'), 'numHits': 3, 'TF': 0.5384615384615384, 'WTD': 0.025572000236694432, 'inTitle': False}, {'docURL': 'https://commons.wikimedia.org:443/wiki/Category:Malnutrition', 'docObjID': ObjectId('60892018fb7dd753d504e943'), 'numHits': 1, 'TF': 0.5147058823529411, 'WTD': 0.010569737979971655, 'inTitle': False}, {'docURL': 'https://www.mediawiki.org:443/wiki/Wikimedia_Engineering/WMF_Tech_Days_2013', 'docObjID': ObjectId('6089229474aafe60eab5ab42'), 'numHits': 1, 'TF': 0.5333333333333333, 'WTD': 0.018187831682290802, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/History_of_dance', 'docObjID': ObjectId('608923101423671fb0475988'), 'numHits': 1, 'TF': 0.5028248587570622, 'WTD': 0.002962758137381759, 'inTitle': False}, {'docURL': 'http://news.bbc.co.uk:80/2/hi/americas/298608.stm', 'docObjID': ObjectId('60892040fb7dd753d504e955'), 'numHits': 1, 'TF': 0.5172413793103449, 'WTD': 0.01808936513231054, 'inTitle': False}, {'docURL': 'https://www.semantic-mediawiki.org:443/wiki/SMWCon_Spring_2013', 'docObjID': ObjectId('6089229474aafe60eab5ab41'), 'numHits': 1, 'TF': 0.5111111111111111, 'WTD': 0.008192319205190405, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Circle_dance', 'docObjID': ObjectId('608922f31423671fb0475963'), 'numHits': 1, 'TF': 0.5025, 'WTD': 0.00289656803589161, 'inTitle': False}, {'docURL': 'https://www.mediawiki.org:443/wiki/Design/Design_Review', 'docObjID': ObjectId('6089226b74aafe60eab5aafe'), 'numHits': 2, 'TF': 0.5032467532467533, 'WTD': 0.0031083568689184923, 'inTitle': False}, {'docURL': 'https://how2recycle.info:443/', 'docObjID': ObjectId('608924fb0e90df59d1507297'), 'numHits': 2, 'TF': 0.5185185185185185, 'WTD': 0.017731778600337714, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/NBC', 'docObjID': ObjectId('6089244a1423671fb0475aa4'), 'numHits': 1, 'TF': 0.5003933910306845, 'WTD': 0.0005012142212215383, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Rachel_Green', 'docObjID': ObjectId('608924551423671fb0475abe'), 'numHits': 1, 'TF': 0.5006090133982948, 'WTD': 0.0007901855275123411, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Brandy_Norwood', 'docObjID': ObjectId('6089250f1423671fb0475bd5'), 'numHits': 1, 'TF': 0.5009727626459144, 'WTD': 0.0010352943239894776, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Adele', 'docObjID': ObjectId('608925091423671fb0475bcd'), 'numHits': 1, 'TF': 0.5004793863854267, 'WTD': 0.0005794418698263874, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_best-selling_music_artists', 'docObjID': ObjectId('608924f61423671fb0475baf'), 'numHits': 1, 'TF': 0.5010504201680672, 'WTD': 0.0010634387120378272, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Christina_Applegate', 'docObjID': ObjectId('6089243b1423671fb0475a83'), 'numHits': 1, 'TF': 0.5021097046413502, 'WTD': 0.0021418629372376053, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Penn_Jillette', 'docObjID': ObjectId('608924431423671fb0475a95'), 'numHits': 2, 'TF': 0.5035460992907801, 'WTD': 0.00420713400636717, 'inTitle': False}, {'docURL': 'https://tools.ietf.org:443/html/rfc4949', 'docObjID': ObjectId('608924b60e90df59d1507259'), 'numHits': 1, 'TF': 0.5000989119683482, 'WTD': 9.268141193006316e-05, 'inTitle':  ...
# {'_id': ObjectId('608ba2d1b9a90f10cf04143e'), 'lemma': '111th', 'IDF': 3.893769685621529, 'numDocs': 7, 'docList': [{'docURL': 'https://www.congress.gov:443/', 'docObjID': ObjectId('608923db367494592376ae8c'), 'numHits': 1, 'TF': 0.5086206896551724, 'WTD': 0.006326960022125349, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Bulgaria', 'docObjID': ObjectId('608919be63d00e014ef893ae'), 'numHits': 1, 'TF': 0.5005854800936768, 'WTD': 0.0007515829741101169, 'inTitle': False}, {'docURL': 'https://digitalalabama.com:443/alabama-civil-war/alabama-civil-war-timeline/27066', 'docObjID': ObjectId('6089b79482c133359bf950a4'), 'numHits': 4, 'TF': 0.5045045045045045, 'WTD': 0.0033688908263510378, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Index_of_Montana-related_articles', 'docObjID': ObjectId('60891835414adb5d4f9e7bfc'), 'numHits': 1, 'TF': 0.5014285714285714, 'WTD': 0.001830933813981613, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Index_of_Arizona-related_articles', 'docObjID': ObjectId('60891834414adb5d4f9e7bf8'), 'numHits': 1, 'TF': 0.5015243902439024, 'WTD': 0.002074255819852144, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Northern_Mariana_Islands', 'docObjID': ObjectId('608919e063d00e014ef893f8'), 'numHits': 1, 'TF': 0.5008474576271187, 'WTD': 0.0011507632249393752, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Kuwait', 'docObjID': ObjectId('608919d563d00e014ef893e1'), 'numHits': 1, 'TF': 0.5004424778761062, 'WTD': 0.0005795423806739908, 'inTitle': False}]}
# {'_id': ObjectId('608ba2d1b9a90f10cf041442'), 'lemma': '11a', 'IDF': 3.893769685621529, 'numDocs': 7, 'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Istanbul', 'docObjID': ObjectId('60891a8463d00e014ef89513'), 'numHits': 1, 'TF': 0.5004424778761062, 'WTD': 0.0006203514529710473, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_space_shuttle_missions', 'docObjID': ObjectId('608916bd414adb5d4f9e78cb'), 'numHits': 1, 'TF': 0.5018382352941176, 'WTD': 0.0013768411209800064, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/Portal:Japan', 'docObjID': ObjectId('6089179a414adb5d4f9e7ac9'), 'numHits': 2, 'TF': 0.502375296912114, 'WTD': 0.002554549265286607, 'inTitle': False}, {'docURL': 'http://www.designation-systems.net:80/usmilav/412015-L(addendum).html', 'docObjID': ObjectId('608925330e90df59d15072cf'), 'numHits': 3, 'TF': 0.502851711026616, 'WTD': 0.0030419127590896626, 'inTitle': False}, {'docURL': 'https://casetext.com:443/case/jennings-v-rodriguez-2', 'docObjID': ObjectId('6089be1f965a6a6a98fa803b'), 'numHits': 1, 'TF': 0.5003306878306878, 'WTD': 0.00039012385652070975, 'inTitle': False}, {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_ASTM_International_standards', 'docObjID': ObjectId('6089193863d00e014ef8924e'), 'numHits': 6, 'TF': 0.5007878151260504, 'WTD': 0.001077325512980805, 'inTitle': False}, {'docURL': 'https://commons.wikimedia.org:443/wiki/Category:Uses_of_Wikidata_Infobox', 'docObjID': ObjectId('6089b6c834bde3251fe49cc3'), 'numHits': 1, 'TF': 0.5024875621890548, 'WTD': 0.0041347031944719715, 'inTitle': False}]}

# %%
documents = mydb['documents']
url_list = ['https://en.wikipedia.org:443/wiki/ISO/IEC_15693', 'https://tools.ietf.org:443/html/rfc2896']
results = []
for x in documents.find({'url': {'$in': url_list}}):
    results.append({"title": x['title'], "description": x['snippet'], "url": x['url']})
results
# Out:
# [{'title': 'RFC 2896 - Remote Network Monitoring MIB Protocol Identifier Macros',
#   'description': '[Docs] [txt|pdf] [draft-ietf-rmon...] [Tracker] [Diff1] [Diff2] INFORMATIONAL \nNetwork Working Group                                         A. Bierman\nRequests for Comment: 2896                                      C. Bucci\nCategory: Informational                             ',
#   'url': 'https://tools.ietf.org:443/html/rfc2896'},
#  {'title': 'ISO/IEC 15693 - Wikipedia',
#   'description': 'ISO/IEC 15693, is an ISO standard for vicinity cards, i.e. cards which can be read from a greater distance as compared with proximity cards. Such cards can normally be read out by a reader without being powered themselves, as the reader will supply the necessary power to the',
#   'url': 'https://en.wikipedia.org:443/wiki/ISO/IEC_15693'}]

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb+srv://chris:555Project2021@cluster0.kphap.mongodb.net/SearchEngine?retryWrites=true&w=majority")
mydb = myclient["SearchEngine"]
mycol = mydb["indexes"]

mydoc = mycol.find().sort("lemma")
lexicon = {}
URL_WTD = {}

for x in mydoc:
    lexicon[x['lemma']] = {'IDF': x['IDF'], 'docList': x['docList']}
    for doc in x['docList']:
        if doc['docURL'] in URL_WTD.keys():
            URL_WTD[doc['docURL']][x['lemma']] = doc['WTD']
        else:
            URL_WTD[doc['docURL']] = {x['lemma']: doc['WTD']}
lexicon
# Out:
# {'!': {'IDF': 0.6133410017376515,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_years_in_games',
#     'docObjID': ObjectId('6078bf333d9c4c4deb99d760'),
#     'numHits': 4,
#     'TF': 0.511,
#     'WTD': 0.015,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_films:_numbers',
#     'docObjID': ObjectId('6078bf2d3d9c4c4deb99d752'),
#     'numHits': 4,
#     'TF': 0.503,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_postal_codes',
#     'docObjID': ObjectId('6078bf253d9c4c4deb99d743'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_recordings_preserved_in_the_United_States_National_Recording_Registry',
#     'docObjID': ObjectId('6078bf8aafe0307140f78b35'),
#     'numHits': 8,
#     'TF': 0.505,
#     'WTD': 0.007,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Contents/Categories',
#     'docObjID': ObjectId('6078be54cadea00f25759201'),
#     'numHits': 1,
#     'TF': 0.518,
#     'WTD': 0.011,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Contents',
#     'docObjID': ObjectId('6078bd46de97e667216e9488'),
#     'numHits': 1,
#     'TF': 0.505,
#     'WTD': 0.005,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Contents/Reference',
#     'docObjID': ObjectId('6078bec7675f120c577537cc'),
#     'numHits': 1,
#     'TF': 0.515,
#     'WTD': 0.012,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Australian_television_channels',
#     'docObjID': ObjectId('6078bf2f3d9c4c4deb99d758'),
#     'numHits': 12,
#     'TF': 0.527,
#     'WTD': 0.024,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_films:_M',
#     'docObjID': ObjectId('6078bf2e3d9c4c4deb99d753'),
#     'numHits': 20,
#     'TF': 0.504,
#     'WTD': 0.005,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_game_show_hosts',
#     'docObjID': ObjectId('6078bf2a3d9c4c4deb99d74b'),
#     'numHits': 59,
#     'TF': 0.516,
#     'WTD': 0.017,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_genres_of_music',
#     'docObjID': ObjectId('6078bf2b3d9c4c4deb99d74c'),
#     'numHits': 1,
#     'TF': 0.504,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_DC_Comics_publications',
#     'docObjID': ObjectId('6078bf353d9c4c4deb99d766'),
#     'numHits': 10,
#     'TF': 0.506,
#     'WTD': 0.006,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Christmas_carols',
#     'docObjID': ObjectId('6078bf2c3d9c4c4deb99d74f'),
#     'numHits': 7,
#     'TF': 0.502,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Timeline_of_the_French_Revolution',
#     'docObjID': ObjectId('6078bf93afe0307140f78b41'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_film_festivals',
#     'docObjID': ObjectId('6078bf2c3d9c4c4deb99d750'),
#     'numHits': 3,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_women%27s_magazines',
#     'docObjID': ObjectId('6078bf363d9c4c4deb99d76a'),
#     'numHits': 6,
#     'TF': 0.51,
#     'WTD': 0.012,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Library',
#     'docObjID': ObjectId('6078bf263d9c4c4deb99d744'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_digital_library_projects',
#     'docObjID': ObjectId('6078bf273d9c4c4deb99d745'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/1980s_in_film',
#     'docObjID': ObjectId('6078bf2e3d9c4c4deb99d755'),
#     'numHits': 4,
#     'TF': 0.51,
#     'WTD': 0.009,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_genetic_disorders',
#     'docObjID': ObjectId('6078bf91afe0307140f78b3b'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_teen_magazines',
#     'docObjID': ObjectId('6078bf363d9c4c4deb99d76c'),
#     'numHits': 2,
#     'TF': 0.577,
#     'WTD': 0.057,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_fictional_countries',
#     'docObjID': ObjectId('6078bf353d9c4c4deb99d768'),
#     'numHits': 11,
#     'TF': 0.507,
#     'WTD': 0.009,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_musical_events',
#     'docObjID': ObjectId('6078bf2b3d9c4c4deb99d74d'),
#     'numHits': 15,
#     'TF': 0.505,
#     'WTD': 0.007,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_ambient_artists',
#     'docObjID': ObjectId('6078bf2b3d9c4c4deb99d74e'),
#     'numHits': 5,
#     'TF': 0.604,
#     'WTD': 0.07,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/1970s_in_film',
#     'docObjID': ObjectId('6078bf2e3d9c4c4deb99d756'),
#     'numHits': 4,
#     'TF': 0.506,
#     'WTD': 0.007,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_most_expensive_paintings',
#     'docObjID': ObjectId('6078bf8aafe0307140f78b34'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_programs_broadcast_by_UPN',
#     'docObjID': ObjectId('6078bf313d9c4c4deb99d75c'),
#     'numHits': 3,
#     'TF': 0.507,
#     'WTD': 0.008,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_spin-offs',
#     'docObjID': ObjectId('6078bf99afe0307140f78b50'),
#     'numHits': 6,
#     'TF': 0.505,
#     'WTD': 0.005,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_hieroglyphs',
#     'docObjID': ObjectId('6078bfcdd511816771f645ee'),
#     'numHits': 2,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_finite_simple_groups',
#     'docObjID': ObjectId('6078bf9bafe0307140f78b57'),
#     'numHits': 2,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_strikes',
#     'docObjID': ObjectId('6078bfcad511816771f645e6'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_association_footballers_who_died_while_playing',
#     'docObjID': ObjectId('6078bfc8d511816771f645e1'),
#     'numHits': 7,
#     'TF': 0.504,
#     'WTD': 0.006,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_mathematical_symbols',
#     'docObjID': ObjectId('6078bf9bafe0307140f78b56'),
#     'numHits': 14,
#     'TF': 0.518,
#     'WTD': 0.017,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Village_pump_(proposals)/Archive_129',
#     'docObjID': ObjectId('6078c0613cbcc92a995a4381'),
#     'numHits': 31,
#     'TF': 0.511,
#     'WTD': 0.009,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Criteria_for_speedy_deletion',
#     'docObjID': ObjectId('6078c0653cbcc92a995a438b'),
#     'numHits': 3,
#     'TF': 0.503,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Manual_of_Style/Lead_section',
#     'docObjID': ObjectId('6078c086e147ca541fa9426b'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://phabricator.wikimedia.org:443/T20483',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4375'),
#     'numHits': 6,
#     'TF': 0.52,
#     'WTD': 0.018,
#     'inTitle': False},
#    {'docURL': 'https://foundation.wikimedia.org:443/wiki/Terms_of_Use',
#     'docObjID': ObjectId('6078c088e147ca541fa9426f'),
#     'numHits': 4,
#     'TF': 0.505,
#     'WTD': 0.007,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Category:Wikipedia_semi-protected_project_pages',
#     'docObjID': ObjectId('6078c089e147ca541fa94272'),
#     'numHits': 4,
#     'TF': 0.508,
#     'WTD': 0.008,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Special:Diff/740835205',
#     'docObjID': ObjectId('6078c0623cbcc92a995a4382'),
#     'numHits': 4,
#     'TF': 0.507,
#     'WTD': 0.007,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Administrators%27_guide/Protecting',
#     'docObjID': ObjectId('6078c0633cbcc92a995a4385'),
#     'numHits': 1,
#     'TF': 0.504,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia_talk:Protection_policy',
#     'docObjID': ObjectId('6078c089e147ca541fa94273'),
#     'numHits': 3,
#     'TF': 0.523,
#     'WTD': 0.023,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Userboxes',
#     'docObjID': ObjectId('6078c087e147ca541fa9426d'),
#     'numHits': 2,
#     'TF': 0.507,
#     'WTD': 0.005,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Civility',
#     'docObjID': ObjectId('6078c0643cbcc92a995a4388'),
#     'numHits': 4,
#     'TF': 0.51,
#     'WTD': 0.011,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Disruptive_editing',
#     'docObjID': ObjectId('6078c0653cbcc92a995a438a'),
#     'numHits': 2,
#     'TF': 0.508,
#     'WTD': 0.008,
#     'inTitle': False},
#    {'docURL': 'https://meta.wikimedia.org:443/wiki/Protected_pages_considered_harmful',
#     'docObjID': ObjectId('6078c0613cbcc92a995a4380'),
#     'numHits': 1,
#     'TF': 0.52,
#     'WTD': 0.017,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Template:Pp-move',
#     'docObjID': ObjectId('6078c0603cbcc92a995a437e'),
#     'numHits': 1,
#     'TF': 0.51,
#     'WTD': 0.008,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Template:Redirect_category_shell',
#     'docObjID': ObjectId('6078c0613cbcc92a995a437f'),
#     'numHits': 7,
#     'TF': 0.506,
#     'WTD': 0.007,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Be_bold',
#     'docObjID': ObjectId('6078c083e147ca541fa94266'),
#     'numHits': 2,
#     'TF': 0.51,
#     'WTD': 0.01,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Community_portal',
#     'docObjID': ObjectId('6078c08de147ca541fa9428b'),
#     'numHits': 15,
#     'TF': 0.534,
#     'WTD': 0.033,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Hatnote',
#     'docObjID': ObjectId('6078c083e147ca541fa94269'),
#     'numHits': 3,
#     'TF': 0.504,
#     'WTD': 0.003,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Editnotice',
#     'docObjID': ObjectId('6078c0603cbcc92a995a437d'),
#     'numHits': 4,
#     'TF': 0.515,
#     'WTD': 0.012,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/German_Wikipedia',
#     'docObjID': ObjectId('6078c05f3cbcc92a995a4377'),
#     'numHits': 2,
#     'TF': 0.503,
#     'WTD': 0.003,
#     'inTitle': False},
#    {'docURL': 'https://www.mediawiki.org:443/wiki/WMF_product_development_process/2015-11-05',
#     'docObjID': ObjectId('6078c05f3cbcc92a995a437a'),
#     'numHits': 2,
#     'TF': 0.517,
#     'WTD': 0.015,
#     'inTitle': False},
#    {'docURL': 'https://fa.wikipedia.org:443/wiki/%D8%AF%D8%B1%DA%AF%D8%A7%D9%87:%D8%AF%D8%B1%D9%88%D9%86%D9%85%D8%A7%DB%8C%D9%87/%D9%81%D9%87%D8%B1%D8%B3%D8%AA%E2%80%8C%D9%87%D8%A7',
#     'docObjID': ObjectId('6078c0523cbcc92a995a433b'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_national_anthems',
#     'docObjID': ObjectId('6078c0353cbcc92a995a42e9'),
#     'numHits': 14,
#     'TF': 0.504,
#     'WTD': 0.007,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Spoken_articles',
#     'docObjID': ObjectId('6078c04c3cbcc92a995a4320'),
#     'numHits': 2,
#     'TF': 0.503,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:File_Upload_Wizard',
#     'docObjID': ObjectId('6078c0503cbcc92a995a4329'),
#     'numHits': 8,
#     'TF': 0.514,
#     'WTD': 0.016,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Edit_requests',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4371'),
#     'numHits': 1,
#     'TF': 0.504,
#     'WTD': 0.003,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Transclusion',
#     'docObjID': ObjectId('6078c05c3cbcc92a995a436b'),
#     'numHits': 13,
#     'TF': 0.526,
#     'WTD': 0.021,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Cascading_style_sheets',
#     'docObjID': ObjectId('6078c05c3cbcc92a995a4367'),
#     'numHits': 1,
#     'TF': 0.503,
#     'WTD': 0.003,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Reviewing_pending_changes',
#     'docObjID': ObjectId('6078c05a3cbcc92a995a4362'),
#     'numHits': 1,
#     'TF': 0.504,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_operating_systems',
#     'docObjID': ObjectId('6078c03e3cbcc92a995a42f9'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Category:Articles_using_small_message_boxes',
#     'docObjID': ObjectId('6078c04f3cbcc92a995a4325'),
#     'numHits': 1,
#     'TF': 0.512,
#     'WTD': 0.009,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/ISO_8859-3',
#     'docObjID': ObjectId('6078c0403cbcc92a995a42ff'),
#     'numHits': 1,
#     'TF': 0.505,
#     'WTD': 0.006,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:RFED',
#     'docObjID': ObjectId('6078c0593cbcc92a995a435e'),
#     'numHits': 1,
#     'TF': 0.505,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Requests_for_page_protection',
#     'docObjID': ObjectId('6078c0543cbcc92a995a4351'),
#     'numHits': 1,
#     'TF': 0.505,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_automobile_manufacturers',
#     'docObjID': ObjectId('6078c0463cbcc92a995a4314'),
#     'numHits': 1,
#     'TF': 0.504,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_solar_thermal_power_stations',
#     'docObjID': ObjectId('6078c03c3cbcc92a995a42f6'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Blocking_policy',
#     'docObjID': ObjectId('6078c0553cbcc92a995a4354'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_memory_biases',
#     'docObjID': ObjectId('6078c0383cbcc92a995a42ec'),
#     'numHits': 1,
#     'TF': 0.506,
#     'WTD': 0.005,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:LUA',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4370'),
#     'numHits': 8,
#     'TF': 0.54,
#     'WTD': 0.034,
#     'inTitle': False},
#    {'docURL': 'https://sq.wikipedia.org:443/wiki/Portal:P%C3%ABrmbajtja/Lista_e_temave',
#     'docObjID': ObjectId('6078c0533cbcc92a995a4343'),
#     'numHits': 1,
#     'TF': 0.531,
#     'WTD': 0.031,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia_talk:Cascade-protected_items',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4372'),
#     'numHits': 20,
#     'TF': 0.567,
#     'WTD': 0.052,
#     'inTitle': False},
#    {'docURL': 'https://foundation.wikimedia.org:443/wiki/Cookie_statement',
#     'docObjID': ObjectId('6078c0543cbcc92a995a4350'),
#     'numHits': 1,
#     'TF': 0.508,
#     'WTD': 0.008,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_bridges_in_India',
#     'docObjID': ObjectId('6078c0473cbcc92a995a4316'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '! "': {'IDF': 1.5399120845791179,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_operating_systems',
#     'docObjID': ObjectId('6078c03e3cbcc92a995a42f9'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:LUA',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4370'),
#     'numHits': 4,
#     'TF': 0.52,
#     'WTD': 0.017,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_national_anthems',
#     'docObjID': ObjectId('6078c0353cbcc92a995a42e9'),
#     'numHits': 8,
#     'TF': 0.503,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_association_footballers_who_died_while_playing',
#     'docObjID': ObjectId('6078bfc8d511816771f645e1'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Timeline_of_the_French_Revolution',
#     'docObjID': ObjectId('6078bf93afe0307140f78b41'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Christmas_carols',
#     'docObjID': ObjectId('6078bf2c3d9c4c4deb99d74f'),
#     'numHits': 5,
#     'TF': 0.502,
#     'WTD': 0.003,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_musical_events',
#     'docObjID': ObjectId('6078bf2b3d9c4c4deb99d74d'),
#     'numHits': 2,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_digital_library_projects',
#     'docObjID': ObjectId('6078bf273d9c4c4deb99d745'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Disruptive_editing',
#     'docObjID': ObjectId('6078c0653cbcc92a995a438a'),
#     'numHits': 1,
#     'TF': 0.504,
#     'WTD': 0.004,
#     'inTitle': False}]},
#  '! )': {'IDF': 1.4527619088602177,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Community_portal',
#     'docObjID': ObjectId('6078c08de147ca541fa9428b'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Village_pump_(proposals)/Archive_129',
#     'docObjID': ObjectId('6078c0613cbcc92a995a4381'),
#     'numHits': 3,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://phabricator.wikimedia.org:443/T20483',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4375'),
#     'numHits': 2,
#     'TF': 0.507,
#     'WTD': 0.006,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Disruptive_editing',
#     'docObjID': ObjectId('6078c0653cbcc92a995a438a'),
#     'numHits': 1,
#     'TF': 0.504,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Special:Diff/740835205',
#     'docObjID': ObjectId('6078c0623cbcc92a995a4382'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:File_Upload_Wizard',
#     'docObjID': ObjectId('6078c0503cbcc92a995a4329'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:RFED',
#     'docObjID': ObjectId('6078c0593cbcc92a995a435e'),
#     'numHits': 1,
#     'TF': 0.505,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia_talk:Cascade-protected_items',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4372'),
#     'numHits': 1,
#     'TF': 0.503,
#     'WTD': 0.003,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Requests_for_page_protection',
#     'docObjID': ObjectId('6078c0543cbcc92a995a4351'),
#     'numHits': 1,
#     'TF': 0.505,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Transclusion',
#     'docObjID': ObjectId('6078c05c3cbcc92a995a436b'),
#     'numHits': 2,
#     'TF': 0.504,
#     'WTD': 0.003,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Australian_television_channels',
#     'docObjID': ObjectId('6078bf2f3d9c4c4deb99d758'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '! ]': {'IDF': 2.1931245983544616,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_association_footballers_who_died_while_playing',
#     'docObjID': ObjectId('6078bfc8d511816771f645e1'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Transclusion',
#     'docObjID': ObjectId('6078c05c3cbcc92a995a436b'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '! }': {'IDF': 1.8920946026904804,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Transclusion',
#     'docObjID': ObjectId('6078c05c3cbcc92a995a436b'),
#     'numHits': 4,
#     'TF': 0.508,
#     'WTD': 0.006,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Hatnote',
#     'docObjID': ObjectId('6078c083e147ca541fa94269'),
#     'numHits': 2,
#     'TF': 0.503,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_finite_simple_groups',
#     'docObjID': ObjectId('6078bf9bafe0307140f78b57'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_mathematical_symbols',
#     'docObjID': ObjectId('6078bf9bafe0307140f78b56'),
#     'numHits': 2,
#     'TF': 0.503,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '!!': {'IDF': 1.8920946026904804,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_spin-offs',
#     'docObjID': ObjectId('6078bf99afe0307140f78b50'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/1980s_in_film',
#     'docObjID': ObjectId('6078bf2e3d9c4c4deb99d755'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_films:_M',
#     'docObjID': ObjectId('6078bf2e3d9c4c4deb99d753'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_game_show_hosts',
#     'docObjID': ObjectId('6078bf2a3d9c4c4deb99d74b'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False}]},
#  '!! )': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/1980s_in_film',
#     'docObjID': ObjectId('6078bf2e3d9c4c4deb99d755'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '!!!': {'IDF': 2.0170333392987803,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_game_show_hosts',
#     'docObjID': ObjectId('6078bf2a3d9c4c4deb99d74b'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_films:_M',
#     'docObjID': ObjectId('6078bf2e3d9c4c4deb99d753'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/MediaWiki:Titleblacklist',
#     'docObjID': ObjectId('6078c0603cbcc92a995a437c'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '!!! )': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/MediaWiki:Titleblacklist',
#     'docObjID': ObjectId('6078c0603cbcc92a995a437c'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '!!!!': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/MediaWiki:Titleblacklist',
#     'docObjID': ObjectId('6078c0603cbcc92a995a437c'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '!!!! )': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/MediaWiki:Titleblacklist',
#     'docObjID': ObjectId('6078c0603cbcc92a995a437c'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '!?': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/MediaWiki:Titleblacklist',
#     'docObjID': ObjectId('6078c0603cbcc92a995a437c'),
#     'numHits': 4,
#     'TF': 0.503,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '"': {'IDF': 0.004196114593608148,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/German_Wikipedia',
#     'docObjID': ObjectId('6078c05f3cbcc92a995a4377'),
#     'numHits': 105,
#     'TF': 0.673,
#     'WTD': 0.18,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_bridges_in_India',
#     'docObjID': ObjectId('6078c0473cbcc92a995a4316'),
#     'numHits': 168,
#     'TF': 0.731,
#     'WTD': 0.235,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Royal_Navy_ships',
#     'docObjID': ObjectId('6078c0453cbcc92a995a4310'),
#     'numHits': 2,
#     'TF': 0.563,
#     'WTD': 0.044,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Vandalism',
#     'docObjID': ObjectId('6078c0583cbcc92a995a435c'),
#     'numHits': 48,
#     'TF': 0.567,
#     'WTD': 0.075,
#     'inTitle': False},
#    {'docURL': 'https://yo.wikipedia.org:443/wiki/%C3%88b%C3%BAt%C3%A9:%C3%80k%C3%B3%C3%B3n%C3%BA/%C3%80w%E1%BB%8Dn_%C3%A0t%C3%B2j%E1%BB%8D',
#     'docObjID': ObjectId('6078c0533cbcc92a995a434a'),
#     'numHits': 2,
#     'TF': 0.533,
#     'WTD': 0.027,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Ships_of_the_Royal_Netherlands_Navy',
#     'docObjID': ObjectId('6078c0453cbcc92a995a430f'),
#     'numHits': 50,
#     'TF': 0.91,
#     'WTD': 0.269,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Office_actions',
#     'docObjID': ObjectId('6078c05b3cbcc92a995a4365'),
#     'numHits': 12,
#     'TF': 0.625,
#     'WTD': 0.117,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_solar_thermal_power_stations',
#     'docObjID': ObjectId('6078c03c3cbcc92a995a42f6'),
#     'numHits': 200,
#     'TF': 0.759,
#     'WTD': 0.225,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Web_experiment_list',
#     'docObjID': ObjectId('6078c0393cbcc92a995a42ee'),
#     'numHits': 28,
#     'TF': 0.649,
#     'WTD': 0.132,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Contents/People_and_self',
#     'docObjID': ObjectId('6078c04d3cbcc92a995a4322'),
#     'numHits': 18,
#     'TF': 0.821,
#     'WTD': 0.269,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Category:Redirect_targets_of_redirected_portals_with_existing_subpages',
#     'docObjID': ObjectId('6078c04f3cbcc92a995a4324'),
#     'numHits': 6,
#     'TF': 0.548,
#     'WTD': 0.053,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Edit_requests',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4371'),
#     'numHits': 26,
#     'TF': 0.61,
#     'WTD': 0.086,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Arab%E2%80%93Israeli_conflict',
#     'docObjID': ObjectId('6078c05a3cbcc92a995a4364'),
#     'numHits': 246,
#     'TF': 0.691,
#     'WTD': 0.217,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Category:Articles_using_small_message_boxes',
#     'docObjID': ObjectId('6078c04f3cbcc92a995a4325'),
#     'numHits': 7,
#     'TF': 0.581,
#     'WTD': 0.06,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Administrators',
#     'docObjID': ObjectId('6078c0593cbcc92a995a4361'),
#     'numHits': 70,
#     'TF': 0.631,
#     'WTD': 0.133,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_motorways_in_the_United_Kingdom',
#     'docObjID': ObjectId('6078c0473cbcc92a995a4315'),
#     'numHits': 104,
#     'TF': 0.689,
#     'WTD': 0.197,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Transclusion',
#     'docObjID': ObjectId('6078c05c3cbcc92a995a436b'),
#     'numHits': 48,
#     'TF': 0.597,
#     'WTD': 0.076,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:User_access_levels',
#     'docObjID': ObjectId('6078c0563cbcc92a995a4355'),
#     'numHits': 40,
#     'TF': 0.572,
#     'WTD': 0.056,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_photovoltaic_power_stations',
#     'docObjID': ObjectId('6078c03c3cbcc92a995a42f5'),
#     'numHits': 202,
#     'TF': 0.769,
#     'WTD': 0.249,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Royal_Canadian_Air_Force_stations',
#     'docObjID': ObjectId('6078c0403cbcc92a995a4302'),
#     'numHits': 14,
#     'TF': 0.527,
#     'WTD': 0.029,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_automobile_manufacturers',
#     'docObjID': ObjectId('6078c0463cbcc92a995a4314'),
#     'numHits': 6,
#     'TF': 0.522,
#     'WTD': 0.021,
#     'inTitle': False},
#    {'docURL': 'https://meta.wikimedia.org:443/wiki/Superprotect',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4374'),
#     'numHits': 9,
#     'TF': 0.618,
#     'WTD': 0.105,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_HTTP_status_codes',
#     'docObjID': ObjectId('6078c03e3cbcc92a995a42fc'),
#     'numHits': 210,
#     'TF': 0.695,
#     'WTD': 0.257,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Contents/Mathematics_and_logic',
#     'docObjID': ObjectId('6078c04d3cbcc92a995a4321'),
#     'numHits': 4,
#     'TF': 0.528,
#     'WTD': 0.032,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia_talk:Cascade-protected_items',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4372'),
#     'numHits': 56,
#     'TF': 0.687,
#     'WTD': 0.147,
#     'inTitle': False},
#    {'docURL': 'https://www.mediawiki.org:443/wiki/WMF_product_development_process/2015-11-05',
#     'docObjID': ObjectId('6078c05f3cbcc92a995a437a'),
#     'numHits': 2,
#     'TF': 0.517,
#     'WTD': 0.015,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Portal:Current_events',
#     'docObjID': ObjectId('6078c04f3cbcc92a995a4327'),
#     'numHits': 34,
#     'TF': 0.563,
#     'WTD': 0.041,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_airports_in_Japan',
#     'docObjID': ObjectId('6078c0463cbcc92a995a4313'),
#     'numHits': 12,
#     'TF': 0.511,
#     'WTD': 0.011,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_aircraft_by_date_and_usage_category',
#     'docObjID': ObjectId('6078c0453cbcc92a995a4312'),
#     'numHits': 4,
#     'TF': 0.508,
#     'WTD': 0.012,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:3RR',
#     'docObjID': ObjectId('6078c0553cbcc92a995a4352'),
#     'numHits': 32,
#     'TF': 0.633,
#     'WTD': 0.117,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:RFED',
#     'docObjID': ObjectId('6078c0593cbcc92a995a435e'),
#     'numHits': 22,
#     'TF': 0.618,
#     'WTD': 0.093,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_social_psychologists',
#     'docObjID': ObjectId('6078c0393cbcc92a995a42ef'),
#     'numHits': 10,
#     'TF': 0.609,
#     'WTD': 0.104,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Template:Edit_protected',
#     'docObjID': ObjectId('6078c05f3cbcc92a995a437b'),
#     'numHits': 20,
#     'TF': 0.778,
#     'WTD': 0.21,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_aircraft_weapons',
#     'docObjID': ObjectId('6078c0453cbcc92a995a4311'),
#     'numHits': 12,
#     'TF': 0.523,
#     'WTD': 0.028,
#     'inTitle': False},
#    {'docURL': 'https://phabricator.wikimedia.org:443/T10796',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4373'),
#     'numHits': 2,
#     'TF': 0.523,
#     'WTD': 0.02,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Category:Wikipedia_content_policies',
#     'docObjID': ObjectId('6078c0583cbcc92a995a435b'),
#     'numHits': 4,
#     'TF': 0.567,
#     'WTD': 0.059,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_British_armies_in_WWII',
#     'docObjID': ObjectId('6078c0423cbcc92a995a4309'),
#     'numHits': 2,
#     'TF': 0.55,
#     'WTD': 0.035,
#     'inTitle': False},
#    {'docURL': 'https://meta.wikimedia.org:443/wiki/Office_actions',
#     'docObjID': ObjectId('6078c05c3cbcc92a995a4368'),
#     'numHits': 10,
#     'TF': 0.522,
#     'WTD': 0.023,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_children%27s_rights_topics',
#     'docObjID': ObjectId('6078c0393cbcc92a995a42f0'),
#     'numHits': 4,
#     'TF': 0.553,
#     'WTD': 0.045,
#     'inTitle': False},
#    {'docURL': 'https://foundation.wikimedia.org:443/wiki/Cookie_statement',
#     'docObjID': ObjectId('6078c0543cbcc92a995a4350'),
#     'numHits': 4,
#     'TF': 0.534,
#     'WTD': 0.031,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wiki',
#     'docObjID': ObjectId('6078c0553cbcc92a995a4353'),
#     'numHits': 218,
#     'TF': 0.732,
#     'WTD': 0.289,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Cascading_style_sheets',
#     'docObjID': ObjectId('6078c05c3cbcc92a995a4367'),
#     'numHits': 34,
#     'TF': 0.612,
#     'WTD': 0.115,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_GNU_packages',
#     'docObjID': ObjectId('6078c03e3cbcc92a995a42fa'),
#     'numHits': 52,
#     'TF': 0.639,
#     'WTD': 0.147,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_British_armies_in_WWI',
#     'docObjID': ObjectId('6078c0423cbcc92a995a4308'),
#     'numHits': 2,
#     'TF': 0.542,
#     'WTD': 0.033,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Reviewing_pending_changes',
#     'docObjID': ObjectId('6078c05a3cbcc92a995a4362'),
#     'numHits': 14,
#     'TF': 0.553,
#     'WTD': 0.056,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_social_science_journals',
#     'docObjID': ObjectId('6078c03a3cbcc92a995a42f1'),
#     'numHits': 2,
#     'TF': 0.511,
#     'WTD': 0.012,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Blocking_policy',
#     'docObjID': ObjectId('6078c0553cbcc92a995a4354'),
#     'numHits': 54,
#     'TF': 0.569,
#     'WTD': 0.074,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_operating_systems',
#     'docObjID': ObjectId('6078c03e3cbcc92a995a42f9'),
#     'numHits': 65,
#     'TF': 0.574,
#     'WTD': 0.068,
#     'inTitle': False},
#    {'docURL': 'https://id.wikipedia.org:443/wiki/Wikipedia:Isi/Daftar',
#     'docObjID': ObjectId('6078c0523cbcc92a995a433a'),
#     'numHits': 2,
#     'TF': 0.545,
#     'WTD': 0.027,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#     'docObjID': ObjectId('6078c0533cbcc92a995a4346'),
#     'numHits': 46,
#     'TF': 0.598,
#     'WTD': 0.121,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Contents/Technology_and_applied_sciences',
#     'docObjID': ObjectId('6078c03a3cbcc92a995a42f2'),
#     'numHits': 8,
#     'TF': 0.513,
#     'WTD': 0.016,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_regiments_of_the_British_Indian_Army_(1922)',
#     'docObjID': ObjectId('6078c0423cbcc92a995a4307'),
#     'numHits': 2,
#     'TF': 0.517,
#     'WTD': 0.013,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Template:Edit_semi-protected',
#     'docObjID': ObjectId('6078c0583cbcc92a995a435a'),
#     'numHits': 18,
#     'TF': 0.773,
#     'WTD': 0.216,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_world%27s_tallest_dams',
#     'docObjID': ObjectId('6078c03d3cbcc92a995a42f8'),
#     'numHits': 34,
#     'TF': 0.555,
#     'WTD': 0.056,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_memory_biases',
#     'docObjID': ObjectId('6078c0383cbcc92a995a42ec'),
#     'numHits': 23,
#     'TF': 0.644,
#     'WTD': 0.114,
#     'inTitle': False},
#    {'docURL': 'https://as.wikipedia.org:443/wiki/%E0%A7%B1%E0%A6%BF%E0%A6%95%E0%A6%BF%E0%A6%9A%27%E0%A7%B0%E0%A6%BE:%E0%A6%AA%E0%A6%9E%E0%A7%8D%E0%A6%9C%E0%A7%80/%E0%A6%A4%E0%A6%BE%E0%A6%B2%E0%A6%BF%E0%A6%95%E0%A6%BE%E0%A6%B8%E0%A6%AE%E0%A7%82%E0%A6%B9',
#     'docObjID': ObjectId('6078c0513cbcc92a995a4335'),
#     'numHits': 2,
#     'TF': 0.533,
#     'WTD': 0.026,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Royal_Navy_aircraft_wings',
#     'docObjID': ObjectId('6078c0413cbcc92a995a4306'),
#     'numHits': 2,
#     'TF': 0.525,
#     'WTD': 0.019,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_largest_suspension_bridges',
#     'docObjID': ObjectId('6078c0493cbcc92a995a431b'),
#     'numHits': 309,
#     'TF': 0.804,
#     'WTD': 0.234,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Spoken_articles',
#     'docObjID': ObjectId('6078c04c3cbcc92a995a4320'),
#     'numHits': 8,
#     'TF': 0.513,
#     'WTD': 0.015,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Editnotice',
#     'docObjID': ObjectId('6078c0603cbcc92a995a437d'),
#     'numHits': 34,
#     'TF': 0.629,
#     'WTD': 0.102,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Marinas',
#     'docObjID': ObjectId('6078c04b3cbcc92a995a431e'),
#     'numHits': 61,
#     'TF': 0.557,
#     'WTD': 0.071,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Windmills_in_the_United_Kingdom',
#     'docObjID': ObjectId('6078c03c3cbcc92a995a42f4'),
#     'numHits': 114,
#     'TF': 0.788,
#     'WTD': 0.207,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_battles',
#     'docObjID': ObjectId('6078c0433cbcc92a995a430a'),
#     'numHits': 2,
#     'TF': 0.516,
#     'WTD': 0.018,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Lighthouses_and_lightvessels_in_Germany',
#     'docObjID': ObjectId('6078c03b3cbcc92a995a42f3'),
#     'numHits': 42,
#     'TF': 0.636,
#     'WTD': 0.112,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_newsgroups',
#     'docObjID': ObjectId('6078c03e3cbcc92a995a42fb'),
#     'numHits': 16,
#     'TF': 0.587,
#     'WTD': 0.104,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_reservoirs_and_dams',
#     'docObjID': ObjectId('6078c03d3cbcc92a995a42f7'),
#     'numHits': 2,
#     'TF': 0.501,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_spacecraft',
#     'docObjID': ObjectId('6078c04a3cbcc92a995a431d'),
#     'numHits': 2,
#     'TF': 0.527,
#     'WTD': 0.027,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/User:Example/monobook.css',
#     'docObjID': ObjectId('6078c0573cbcc92a995a4359'),
#     'numHits': 6,
#     'TF': 0.676,
#     'WTD': 0.139,
#     'inTitle': False},
#    {'docURL': 'https://www.wikidata.org:443/wiki/Special:EntityPage/Q14615401',
#     'docObjID': ObjectId('6078c0533cbcc92a995a4349'),
#     'numHits': 2,
#     'TF': 0.54,
#     'WTD': 0.039,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/ISO_8859-3',
#     'docObjID': ObjectId('6078c0403cbcc92a995a42ff'),
#     'numHits': 7,
#     'TF': 0.534,
#     'WTD': 0.039,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/American_Army_Groups_in_WWII',
#     'docObjID': ObjectId('6078c0433cbcc92a995a430b'),
#     'numHits': 2,
#     'TF': 0.531,
#     'WTD': 0.026,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:General_sanctions/India%E2%80%93Pakistan_conflict',
#     'docObjID': ObjectId('6078c05a3cbcc92a995a4363'),
#     'numHits': 2,
#     'TF': 0.524,
#     'WTD': 0.018,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Requests_for_page_protection',
#     'docObjID': ObjectId('6078c0543cbcc92a995a4351'),
#     'numHits': 22,
#     'TF': 0.618,
#     'WTD': 0.093,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_aircraft_of_the_Luftwaffe,_World_War_II',
#     'docObjID': ObjectId('6078c0443cbcc92a995a430d'),
#     'numHits': 8,
#     'TF': 0.542,
#     'WTD': 0.033,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_armies_by_number',
#     'docObjID': ObjectId('6078c0413cbcc92a995a4305'),
#     'numHits': 4,
#     'TF': 0.507,
#     'WTD': 0.008,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_United_States_Army_Air_Forces_Air_Force_Component_Commands',
#     'docObjID': ObjectId('6078c0413cbcc92a995a4303'),
#     'numHits': 2,
#     'TF': 0.522,
#     'WTD': 0.03,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_military_aircraft_of_the_Soviet_Union_and_the_CIS',
#     'docObjID': ObjectId('6078c0443cbcc92a995a430c'),
#     'numHits': 82,
#     'TF': 0.586,
#     'WTD': 0.116,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:COPYVIO',
#     'docObjID': ObjectId('6078c0573cbcc92a995a4358'),
#     'numHits': 8,
#     'TF': 0.536,
#     'WTD': 0.031,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/MediaWiki:Titleblacklist',
#     'docObjID': ObjectId('6078c0603cbcc92a995a437c'),
#     'numHits': 15,
#     'TF': 0.512,
#     'WTD': 0.009,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Ajax_frameworks',
#     'docObjID': ObjectId('6078c03f3cbcc92a995a42fe'),
#     'numHits': 14,
#     'TF': 0.623,
#     'WTD': 0.101,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Main_Page/Tomorrow',
#     'docObjID': ObjectId('6078c05c3cbcc92a995a436a'),
#     'numHits': 10,
#     'TF': 0.639,
#     'WTD': 0.119,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_tunnels_in_Iceland',
#     'docObjID': ObjectId('6078c0493cbcc92a995a431c'),
#     'numHits': 12,
#     'TF': 0.654,
#     'WTD': 0.135,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_tunnels',
#     'docObjID': ObjectId('6078c0493cbcc92a995a4319'),
#     'numHits': 2,
#     'TF': 0.577,
#     'WTD': 0.064,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Shortcut',
#     'docObjID': ObjectId('6078c04e3cbcc92a995a4323'),
#     'numHits': 22,
#     'TF': 0.563,
#     'WTD': 0.062,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_tunnels_in_Chile',
#     'docObjID': ObjectId('6078c0493cbcc92a995a431a'),
#     'numHits': 2,
#     'TF': 0.538,
#     'WTD': 0.051,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_neurological_disorders',
#     'docObjID': ObjectId('6078c0383cbcc92a995a42ed'),
#     'numHits': 4,
#     'TF': 0.524,
#     'WTD': 0.027,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Libel',
#     'docObjID': ObjectId('6078c0573cbcc92a995a4357'),
#     'numHits': 4,
#     'TF': 0.591,
#     'WTD': 0.077,
#     'inTitle': False},
#    {'docURL': 'https://ne.wikipedia.org:443/wiki/%E0%A4%AA%E0%A5%8B%E0%A4%B0%E0%A5%8D%E0%A4%9F%E0%A4%B2:%E0%A4%B8%E0%A4%BE%E0%A4%AE%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%B9%E0%A4%B0%E0%A5%82/%E0%A4%B8%E0%A5%82%E0%A4%9A%E0%A5%80%E0%A4%B9%E0%A4%B0%E0%A5%82',
#     'docObjID': ObjectId('6078c0523cbcc92a995a433f'),
#     'numHits': 2,
#     'TF': 0.51,
#     'WTD': 0.014,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_national_anthems',
#     'docObjID': ObjectId('6078c0353cbcc92a995a42e9'),
#     'numHits': 1583,
#     'TF': 1.0,
#     'WTD': 0.837,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:File_Upload_Wizard',
#     'docObjID': ObjectId('6078c0503cbcc92a995a4329'),
#     'numHits': 69,
#     'TF': 0.623,
#     'WTD': 0.136,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Thirty-Six_Strategies',
#     'docObjID': ObjectId('6078c0403cbcc92a995a4300'),
#     'numHits': 44,
#     'TF': 0.598,
#     'WTD': 0.12,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_aircraft_of_the_RCAF',
#     'docObjID': ObjectId('6078c0443cbcc92a995a430e'),
#     'numHits': 10,
#     'TF': 0.517,
#     'WTD': 0.014,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_bridges_in_Madagascar',
#     'docObjID': ObjectId('6078c0483cbcc92a995a4317'),
#     'numHits': 6,
#     'TF': 0.773,
#     'WTD': 0.198,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_sailboat_types',
#     'docObjID': ObjectId('6078c04b3cbcc92a995a431f'),
#     'numHits': 1613,
#     'TF': 0.857,
#     'WTD': 0.386,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Royal_Air_Force_groups',
#     'docObjID': ObjectId('6078c0413cbcc92a995a4304'),
#     'numHits': 36,
#     'TF': 0.543,
#     'WTD': 0.034,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_RAF_stations',
#     'docObjID': ObjectId('6078c0403cbcc92a995a4301'),
#     'numHits': 176,
#     'TF': 0.691,
#     'WTD': 0.233,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Requests_for_permissions/Confirmed',
#     'docObjID': ObjectId('6078c0583cbcc92a995a435d'),
#     'numHits': 2,
#     'TF': 0.559,
#     'WTD': 0.04,
#     'inTitle': False},
#    {'docURL': 'https://sd.wikipedia.org:443/wiki/%D8%A8%D8%A7%D8%A8:%D9%81%D9%87%D8%B1%D8%B3%D8%AA_%D9%85%D8%AA%D9%86',
#     'docObjID': ObjectId('6078c0533cbcc92a995a4344'),
#     'numHits': 2,
#     'TF': 0.611,
#     'WTD': 0.057,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_bridges_in_the_Republic_of_Ireland',
#     'docObjID': ObjectId('6078c0483cbcc92a995a4318'),
#     'numHits': 4,
#     'TF': 0.521,
#     'WTD': 0.027,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Template:In_the_news',
#     'docObjID': ObjectId('6078c05d3cbcc92a995a436c'),
#     'numHits': 4,
#     'TF': 0.58,
#     'WTD': 0.067,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/File:Create-protection-shackle.svg',
#     'docObjID': ObjectId('6078c0563cbcc92a995a4356'),
#     'numHits': 2,
#     'TF': 0.511,
#     'WTD': 0.012,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Base_Class_Library',
#     'docObjID': ObjectId('6078c03f3cbcc92a995a42fd'),
#     'numHits': 4,
#     'TF': 0.523,
#     'WTD': 0.019,
#     'inTitle': False},
#    {'docURL': 'https://commons.wikimedia.org:443/wiki/User:KrinkleBot',
#     'docObjID': ObjectId('6078c05d3cbcc92a995a436d'),
#     'numHits': 6,
#     'TF': 0.625,
#     'WTD': 0.098,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Main_Page_featured_article_protection',
#     'docObjID': ObjectId('6078c0593cbcc92a995a435f'),
#     'numHits': 4,
#     'TF': 0.569,
#     'WTD': 0.05,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Main_Page',
#     'docObjID': ObjectId('6078c04f3cbcc92a995a4326'),
#     'numHits': 10,
#     'TF': 0.602,
#     'WTD': 0.114,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:LUA',
#     'docObjID': ObjectId('6078c05e3cbcc92a995a4370'),
#     'numHits': 38,
#     'TF': 0.69,
#     'WTD': 0.161,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Today%27s_featured_article',
#     'docObjID': ObjectId('6078c0593cbcc92a995a4360'),
#     'numHits': 4,
#     'TF': 0.565,
#     'WTD': 0.049,
#     'inTitle': False},
#    {'docURL': 'https://sq.wikipedia.org:443/wiki/Portal:P%C3%ABrmbajtja/Lista_e_temave',
#     'docObjID': ObjectId('6078c0533cbcc92a995a4343'),
#     'numHits': 2,
#     'TF': 0.563,
#     'WTD': 0.061,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/1970s_in_film',
#     'docObjID': ObjectId('6078bf2e3d9c4c4deb99d756'),
#     'numHits': 140,
#     'TF': 0.719,
#     'WTD': 0.249,
#     'inTitle': False},
# ...
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" decoration': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_recordings_preserved_in_the_United_States_National_Recording_Registry',
#     'docObjID': ObjectId('6078bf8aafe0307140f78b35'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" def': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Cascading_style_sheets',
#     'docObjID': ObjectId('6078c05c3cbcc92a995a4367'),
#     'numHits': 1,
#     'TF': 0.503,
#     'WTD': 0.003,
#     'inTitle': False}]},
#  '" defence': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_RAF_stations',
#     'docObjID': ObjectId('6078c0403cbcc92a995a4301'),
#     'numHits': 2,
#     'TF': 0.502,
#     'WTD': 0.003,
#     'inTitle': False}]},
#  '" defender': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_national_anthems',
#     'docObjID': ObjectId('6078c0353cbcc92a995a42e9'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" defiance': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_fictional_countries',
#     'docObjID': ObjectId('6078bf353d9c4c4deb99d768'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" definition': {'IDF': 2.0170333392987803,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_genres_of_music',
#     'docObjID': ObjectId('6078bf2b3d9c4c4deb99d74c'),
#     'numHits': 1,
#     'TF': 0.504,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Fields_of_science',
#     'docObjID': ObjectId('6078bf9cafe0307140f78b58'),
#     'numHits': 2,
#     'TF': 0.503,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Clouds',
#     'docObjID': ObjectId('6078bfc7d511816771f645de'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" dehler': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_sailboat_types',
#     'docObjID': ObjectId('6078c04b3cbcc92a995a431f'),
#     'numHits': 2,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False}]},
#  '" deity': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_geological_features_on_Venus',
#     'docObjID': ObjectId('6078bfc0d511816771f645cc'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" delaware': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_largest_suspension_bridges',
#     'docObjID': ObjectId('6078c0493cbcc92a995a431b'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" delete': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Administrators%27_guide/Fixing_cut-and-paste_moves',
#     'docObjID': ObjectId('6078c0633cbcc92a995a4384'),
#     'numHits': 1,
#     'TF': 0.503,
#     'WTD': 0.003,
#     'inTitle': False}]},
#  '" delingha': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_solar_thermal_power_stations',
#     'docObjID': ObjectId('6078c03c3cbcc92a995a42f6'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" delta': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_sailboat_types',
#     'docObjID': ObjectId('6078c04b3cbcc92a995a431f'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False}]},
#  '" demand': {'IDF': 2.1931245983544616,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Arab%E2%80%93Israeli_conflict',
#     'docObjID': ObjectId('6078c05a3cbcc92a995a4364'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Village_pump_(proposals)/Archive_129',
#     'docObjID': ObjectId('6078c0613cbcc92a995a4381'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False}]},
#  '" democratic': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_epidemics',
#     'docObjID': ObjectId('6078bf93afe0307140f78b43'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" demographic': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_epidemics',
#     'docObjID': ObjectId('6078bf93afe0307140f78b43'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" den': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Christmas_carols',
#     'docObjID': ObjectId('6078bf2c3d9c4c4deb99d74f'),
#     'numHits': 3,
#     'TF': 0.501,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '" dene': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_national_anthems',
#     'docObjID': ObjectId('6078c0353cbcc92a995a42e9'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" dengue': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_epidemics',
#     'docObjID': ObjectId('6078bf93afe0307140f78b43'),
#     'numHits': 4,
#     'TF': 0.504,
#     'WTD': 0.003,
#     'inTitle': False}]},
#  '" denmark': {'IDF': 2.1931245983544616,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Timeline_of_World_War_I',
#     'docObjID': ObjectId('6078bf93afe0307140f78b40'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_earthquakes',
#     'docObjID': ObjectId('6078bf93afe0307140f78b42'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" denuncian': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_power_outages',
#     'docObjID': ObjectId('6078bf96afe0307140f78b47'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" depict': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_epidemics',
#     'docObjID': ObjectId('6078bf93afe0307140f78b43'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" der': {'IDF': 1.8920946026904804,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Timeline_of_World_War_I',
#     'docObjID': ObjectId('6078bf93afe0307140f78b40'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_association_footballers_who_died_while_playing',
#     'docObjID': ObjectId('6078bfc8d511816771f645e1'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Timeline_of_transportation_technology',
#     'docObjID': ObjectId('6078bf98afe0307140f78b4f'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Arab%E2%80%93Israeli_conflict',
#     'docObjID': ObjectId('6078c05a3cbcc92a995a4364'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" derecho': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_power_outages',
#     'docObjID': ObjectId('6078bf96afe0307140f78b47'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" derry': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Neutral_point_of_view',
#     'docObjID': ObjectId('6078c0643cbcc92a995a4386'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '" descanseu': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Christmas_carols',
#     'docObjID': ObjectId('6078bf2c3d9c4c4deb99d74f'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" deschide': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Christmas_carols',
#     'docObjID': ObjectId('6078bf2c3d9c4c4deb99d74f'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" description': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Hatnote',
#     'docObjID': ObjectId('6078c083e147ca541fa94269'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" desert': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_photovoltaic_power_stations',
#     'docObjID': ObjectId('6078c03c3cbcc92a995a42f5'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" deserted': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Library',
#     'docObjID': ObjectId('6078bf263d9c4c4deb99d744'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" design': {'IDF': 2.1931245983544616,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_bridges_in_India',
#     'docObjID': ObjectId('6078c0473cbcc92a995a4316'),
#     'numHits': 3,
#     'TF': 0.504,
#     'WTD': 0.004,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Web_experiment_list',
#     'docObjID': ObjectId('6078c0393cbcc92a995a42ee'),
#     'numHits': 1,
#     'TF': 0.505,
#     'WTD': 0.005,
#     'inTitle': False}]},
#  '" designation': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Astronomical_symbols',
#     'docObjID': ObjectId('6078bfc5d511816771f645da'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '" designer': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_sailboat_types',
#     'docObjID': ObjectId('6078c04b3cbcc92a995a431f'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False}]},
#  '" despite': {'IDF': 2.1931245983544616,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_operating_systems',
#     'docObjID': ObjectId('6078c03e3cbcc92a995a42f9'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Village_pump_(proposals)/Archive_129',
#     'docObjID': ObjectId('6078c0613cbcc92a995a4381'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False}]},
#  '" det': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Christmas_carols',
#     'docObjID': ObjectId('6078bf2c3d9c4c4deb99d74f'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" detail': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_bridges_in_India',
#     'docObjID': ObjectId('6078c0473cbcc92a995a4316'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" detection': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_interstellar_and_circumstellar_molecules',
#     'docObjID': ObjectId('6078bfbbd511816771f645c5'),
#     'numHits': 9,
#     'TF': 0.509,
#     'WTD': 0.01,
#     'inTitle': False}]},
#  '" development': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Windmills_in_the_United_Kingdom',
#     'docObjID': ObjectId('6078c03c3cbcc92a995a42f4'),
#     'numHits': 1,
#     'TF': 0.503,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '" devon': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_AL_Gold_Glove_Winners_at_Outfield',
#     'docObjID': ObjectId('6078bf323d9c4c4deb99d75e'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False}]},
#  '" dew': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_hieroglyphs',
#     'docObjID': ObjectId('6078bfcdd511816771f645ee'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False}]},
#  '" dewa': {'IDF': 2.1931245983544616,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_solar_thermal_power_stations',
#     'docObjID': ObjectId('6078c03c3cbcc92a995a42f6'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_photovoltaic_power_stations',
#     'docObjID': ObjectId('6078c03c3cbcc92a995a42f5'),
#     'numHits': 2,
#     'TF': 0.503,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '" deșteaptă': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_national_anthems',
#     'docObjID': ObjectId('6078c0353cbcc92a995a42e9'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" diagonal': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_finite_simple_groups',
#     'docObjID': ObjectId('6078bf9bafe0307140f78b57'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" diam': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_sailboat_types',
#     'docObjID': ObjectId('6078c04b3cbcc92a995a431f'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False}]},
#  '" dic': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_most_expensive_paintings',
#     'docObjID': ObjectId('6078bf8aafe0307140f78b34'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" dickerson': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_sailboat_types',
#     'docObjID': ObjectId('6078c04b3cbcc92a995a431f'),
#     'numHits': 2,
#     'TF': 0.5,
#     'WTD': 0.0,
#     'inTitle': False}]},
#  '" dictator': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_games_in_game_theory',
#     'docObjID': ObjectId('6078bf9aafe0307140f78b53'),
#     'numHits': 1,
#     'TF': 0.505,
#     'WTD': 0.005,
#     'inTitle': False}]},
#  '" diction': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Dictionary',
#     'docObjID': ObjectId('6078bf273d9c4c4deb99d746'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '" dictionary': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Dictionary',
#     'docObjID': ObjectId('6078bf273d9c4c4deb99d746'),
#     'numHits': 3,
#     'TF': 0.506,
#     'WTD': 0.006,
#     'inTitle': False}]},
#  '" die': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Timeline_of_transportation_technology',
#     'docObjID': ObjectId('6078bf98afe0307140f78b4f'),
#     'numHits': 1,
#     'TF': 0.502,
#     'WTD': 0.002,
#     'inTitle': False}]},
#  '" diev': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_national_anthems',
#     'docObjID': ObjectId('6078c0353cbcc92a995a42e9'),
#     'numHits': 1,
#     'TF': 0.5,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  '" diff': {'IDF': 2.1931245983544616,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_HTTP_status_codes',
#     'docObjID': ObjectId('6078c03e3cbcc92a995a42fc'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False},
#    {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Reviewing_pending_changes',
#     'docObjID': ObjectId('6078c05a3cbcc92a995a4362'),
#     'numHits': 1,
#     'TF': 0.504,
#     'WTD': 0.004,
#     'inTitle': False}]},
#  '" difference': {'IDF': 2.494154594018443,
#   'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/Clouds',
#     'docObjID': ObjectId('6078bfc7d511816771f645de'),
#     'numHits': 1,
#     'TF': 0.501,
#     'WTD': 0.001,
#     'inTitle': False}]},
#  ...}

# %%
query = {'!': 1, '" die': 1} # term: tf
#lexicon = {'Air Force': {'IDF': 2.3, 'docList': xxx}}
def find_relevant_doc(query):
    doc_list = []
    for token in query.keys():
        for doc in lexicon[token]['docList']:
            doc_list.append(doc['docURL'])
    return doc_list

def compute_score(docURL, query):
    score = 0.0
    for token in query.keys():
        if token in URL_WTD[docURL].keys():
            score += lexicon[token]['IDF'] * query[token] * URL_WTD[docURL][token]
    return score

def sort(doc_list, query):
    unsorted_dict = {}
    for docURL in doc_list:
        unsorted_dict[docURL] = compute_score(docURL, query)
    sorted_dict = {k: v for k, v in sorted(unsorted_dict.items(), key=lambda item: item[1], reverse = True)}
    return list(sorted_dict.keys())
    #return sorted_dict

sort(find_relevant_doc(query), query)
# Out:
# {'https://en.wikipedia.org:443/wiki/List_of_ambient_artists': 0.04293387012163561,
#  'https://en.wikipedia.org:443/wiki/List_of_teen_magazines': 0.034960437099046136,
#  'https://en.wikipedia.org:443/wiki/Wikipedia_talk:Cascade-protected_items': 0.031893732090357875,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:LUA': 0.020853594059080154,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Community_portal': 0.0202402530573425,
#  'https://sq.wikipedia.org:443/wiki/Portal:P%C3%ABrmbajtja/Lista_e_temave': 0.019013571053867195,
#  'https://en.wikipedia.org:443/wiki/List_of_Australian_television_channels': 0.014720184041703636,
#  'https://en.wikipedia.org:443/wiki/Wikipedia_talk:Protection_policy': 0.014106843039965985,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Transclusion': 0.012880161036490681,
#  'https://phabricator.wikimedia.org:443/T20483': 0.011040138031277727,
#  'https://en.wikipedia.org:443/wiki/List_of_game_show_hosts': 0.010426797029540077,
#  'https://en.wikipedia.org:443/wiki/List_of_mathematical_symbols': 0.010426797029540077,
#  'https://meta.wikimedia.org:443/wiki/Protected_pages_considered_harmful': 0.010426797029540077,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:File_Upload_Wizard': 0.009813456027802423,
#  'https://en.wikipedia.org:443/wiki/List_of_years_in_games': 0.009200115026064772,
#  'https://www.mediawiki.org:443/wiki/WMF_product_development_process/2015-11-05': 0.009200115026064772,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Contents/Reference': 0.007360092020851818,
#  'https://en.wikipedia.org:443/wiki/List_of_women%27s_magazines': 0.007360092020851818,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Editnotice': 0.007360092020851818,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Contents/Categories': 0.006746751019114166,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Civility': 0.006746751019114166,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Be_bold': 0.006133410017376515,
#  'https://en.wikipedia.org:443/wiki/1980s_in_film': 0.005520069015638863,
#  'https://en.wikipedia.org:443/wiki/List_of_fictional_countries': 0.005520069015638863,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Village_pump_(proposals)/Archive_129': 0.005520069015638863,
#  'https://en.wikipedia.org:443/wiki/Category:Articles_using_small_message_boxes': 0.005520069015638863,
#  'https://en.wikipedia.org:443/wiki/Timeline_of_transportation_technology': 0.004988309188036886,
#  'https://en.wikipedia.org:443/wiki/List_of_programs_broadcast_by_UPN': 0.004906728013901212,
#  'https://en.wikipedia.org:443/wiki/Category:Wikipedia_semi-protected_project_pages': 0.004906728013901212,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Disruptive_editing': 0.004906728013901212,
#  'https://en.wikipedia.org:443/wiki/Template:Pp-move': 0.004906728013901212,
#  'https://foundation.wikimedia.org:443/wiki/Cookie_statement': 0.004906728013901212,
#  'https://en.wikipedia.org:443/wiki/List_of_recordings_preserved_in_the_United_States_National_Recording_Registry': 0.00429338701216356,
#  'https://en.wikipedia.org:443/wiki/List_of_musical_events': 0.00429338701216356,
#  'https://en.wikipedia.org:443/wiki/1970s_in_film': 0.00429338701216356,
#  'https://foundation.wikimedia.org:443/wiki/Terms_of_Use': 0.00429338701216356,
#  'https://en.wikipedia.org:443/wiki/Special:Diff/740835205': 0.00429338701216356,
#  'https://en.wikipedia.org:443/wiki/Template:Redirect_category_shell': 0.00429338701216356,
#  'https://en.wikipedia.org:443/wiki/List_of_national_anthems': 0.00429338701216356,
#  'https://en.wikipedia.org:443/wiki/List_of_DC_Comics_publications': 0.003680046010425909,
#  'https://en.wikipedia.org:443/wiki/List_of_association_footballers_who_died_while_playing': 0.003680046010425909,
#  'https://en.wikipedia.org:443/wiki/ISO_8859-3': 0.003680046010425909,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Contents': 0.0030667050086882574,
#  'https://en.wikipedia.org:443/wiki/List_of_films:_M': 0.0030667050086882574,
#  'https://en.wikipedia.org:443/wiki/List_of_spin-offs': 0.0030667050086882574,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Userboxes': 0.0030667050086882574,
#  'https://en.wikipedia.org:443/wiki/List_of_memory_biases': 0.0030667050086882574,
#  'https://en.wikipedia.org:443/wiki/List_of_films:_numbers': 0.002453364006950606,
#  'https://en.wikipedia.org:443/wiki/List_of_genres_of_music': 0.002453364006950606,
#  'https://en.wikipedia.org:443/wiki/List_of_Christmas_carols': 0.002453364006950606,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Administrators%27_guide/Protecting': 0.002453364006950606,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Spoken_articles': 0.002453364006950606,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Reviewing_pending_changes': 0.002453364006950606,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:RFED': 0.002453364006950606,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Requests_for_page_protection': 0.002453364006950606,
#  'https://en.wikipedia.org:443/wiki/List_of_automobile_manufacturers': 0.002453364006950606,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Hatnote': 0.0018400230052129545,
#  'https://en.wikipedia.org:443/wiki/German_Wikipedia': 0.0018400230052129545,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Edit_requests': 0.0018400230052129545,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Cascading_style_sheets': 0.0018400230052129545,
#  'https://en.wikipedia.org:443/wiki/List_of_postal_codes': 0.001226682003475303,
#  'https://en.wikipedia.org:443/wiki/List_of_film_festivals': 0.001226682003475303,
#  'https://en.wikipedia.org:443/wiki/List_of_digital_library_projects': 0.001226682003475303,
#  'https://en.wikipedia.org:443/wiki/List_of_genetic_disorders': 0.001226682003475303,
#  'https://en.wikipedia.org:443/wiki/List_of_finite_simple_groups': 0.001226682003475303,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Criteria_for_speedy_deletion': 0.001226682003475303,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Manual_of_Style/Lead_section': 0.001226682003475303,
#  'https://en.wikipedia.org:443/wiki/Timeline_of_the_French_Revolution': 0.0006133410017376515,
#  'https://en.wikipedia.org:443/wiki/Library': 0.0006133410017376515,
#  'https://en.wikipedia.org:443/wiki/List_of_most_expensive_paintings': 0.0006133410017376515,
#  'https://en.wikipedia.org:443/wiki/List_of_hieroglyphs': 0.0006133410017376515,
#  'https://en.wikipedia.org:443/wiki/List_of_strikes': 0.0006133410017376515,
#  'https://fa.wikipedia.org:443/wiki/%D8%AF%D8%B1%DA%AF%D8%A7%D9%87:%D8%AF%D8%B1%D9%88%D9%86%D9%85%D8%A7%DB%8C%D9%87/%D9%81%D9%87%D8%B1%D8%B3%D8%AA%E2%80%8C%D9%87%D8%A7': 0.0006133410017376515,
#  'https://en.wikipedia.org:443/wiki/List_of_operating_systems': 0.0006133410017376515,
#  'https://en.wikipedia.org:443/wiki/List_of_solar_thermal_power_stations': 0.0006133410017376515,
#  'https://en.wikipedia.org:443/wiki/Wikipedia:Blocking_policy': 0.0006133410017376515,
#  'https://en.wikipedia.org:443/wiki/List_of_bridges_in_India': 0.0006133410017376515}

# %%
lexicon['!']
# Out:
# {'IDF': 0.6133410017376515,
#  'docList': [{'docURL': 'https://en.wikipedia.org:443/wiki/List_of_years_in_games',
#    'docObjID': ObjectId('6078bf333d9c4c4deb99d760'),
#    'numHits': 4,
#    'TF': 0.511,
#    'WTD': 0.015,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_films:_numbers',
#    'docObjID': ObjectId('6078bf2d3d9c4c4deb99d752'),
#    'numHits': 4,
#    'TF': 0.503,
#    'WTD': 0.004,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_postal_codes',
#    'docObjID': ObjectId('6078bf253d9c4c4deb99d743'),
#    'numHits': 1,
#    'TF': 0.502,
#    'WTD': 0.002,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_recordings_preserved_in_the_United_States_National_Recording_Registry',
#    'docObjID': ObjectId('6078bf8aafe0307140f78b35'),
#    'numHits': 8,
#    'TF': 0.505,
#    'WTD': 0.007,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Contents/Categories',
#    'docObjID': ObjectId('6078be54cadea00f25759201'),
#    'numHits': 1,
#    'TF': 0.518,
#    'WTD': 0.011,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Contents',
#    'docObjID': ObjectId('6078bd46de97e667216e9488'),
#    'numHits': 1,
#    'TF': 0.505,
#    'WTD': 0.005,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Contents/Reference',
#    'docObjID': ObjectId('6078bec7675f120c577537cc'),
#    'numHits': 1,
#    'TF': 0.515,
#    'WTD': 0.012,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Australian_television_channels',
#    'docObjID': ObjectId('6078bf2f3d9c4c4deb99d758'),
#    'numHits': 12,
#    'TF': 0.527,
#    'WTD': 0.024,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_films:_M',
#    'docObjID': ObjectId('6078bf2e3d9c4c4deb99d753'),
#    'numHits': 20,
#    'TF': 0.504,
#    'WTD': 0.005,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_game_show_hosts',
#    'docObjID': ObjectId('6078bf2a3d9c4c4deb99d74b'),
#    'numHits': 59,
#    'TF': 0.516,
#    'WTD': 0.017,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_genres_of_music',
#    'docObjID': ObjectId('6078bf2b3d9c4c4deb99d74c'),
#    'numHits': 1,
#    'TF': 0.504,
#    'WTD': 0.004,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_DC_Comics_publications',
#    'docObjID': ObjectId('6078bf353d9c4c4deb99d766'),
#    'numHits': 10,
#    'TF': 0.506,
#    'WTD': 0.006,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_Christmas_carols',
#    'docObjID': ObjectId('6078bf2c3d9c4c4deb99d74f'),
#    'numHits': 7,
#    'TF': 0.502,
#    'WTD': 0.004,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Timeline_of_the_French_Revolution',
#    'docObjID': ObjectId('6078bf93afe0307140f78b41'),
#    'numHits': 1,
#    'TF': 0.501,
#    'WTD': 0.001,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_film_festivals',
#    'docObjID': ObjectId('6078bf2c3d9c4c4deb99d750'),
#    'numHits': 3,
#    'TF': 0.502,
#    'WTD': 0.002,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_women%27s_magazines',
#    'docObjID': ObjectId('6078bf363d9c4c4deb99d76a'),
#    'numHits': 6,
#    'TF': 0.51,
#    'WTD': 0.012,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Library',
#    'docObjID': ObjectId('6078bf263d9c4c4deb99d744'),
#    'numHits': 1,
#    'TF': 0.501,
#    'WTD': 0.001,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_digital_library_projects',
#    'docObjID': ObjectId('6078bf273d9c4c4deb99d745'),
#    'numHits': 1,
#    'TF': 0.502,
#    'WTD': 0.002,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/1980s_in_film',
#    'docObjID': ObjectId('6078bf2e3d9c4c4deb99d755'),
#    'numHits': 4,
#    'TF': 0.51,
#    'WTD': 0.009,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_genetic_disorders',
#    'docObjID': ObjectId('6078bf91afe0307140f78b3b'),
#    'numHits': 1,
#    'TF': 0.502,
#    'WTD': 0.002,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_teen_magazines',
#    'docObjID': ObjectId('6078bf363d9c4c4deb99d76c'),
#    'numHits': 2,
#    'TF': 0.577,
#    'WTD': 0.057,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_fictional_countries',
#    'docObjID': ObjectId('6078bf353d9c4c4deb99d768'),
#    'numHits': 11,
#    'TF': 0.507,
#    'WTD': 0.009,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_musical_events',
#    'docObjID': ObjectId('6078bf2b3d9c4c4deb99d74d'),
#    'numHits': 15,
#    'TF': 0.505,
#    'WTD': 0.007,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_ambient_artists',
#    'docObjID': ObjectId('6078bf2b3d9c4c4deb99d74e'),
#    'numHits': 5,
#    'TF': 0.604,
#    'WTD': 0.07,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/1970s_in_film',
#    'docObjID': ObjectId('6078bf2e3d9c4c4deb99d756'),
#    'numHits': 4,
#    'TF': 0.506,
#    'WTD': 0.007,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_most_expensive_paintings',
#    'docObjID': ObjectId('6078bf8aafe0307140f78b34'),
#    'numHits': 1,
#    'TF': 0.501,
#    'WTD': 0.001,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_programs_broadcast_by_UPN',
#    'docObjID': ObjectId('6078bf313d9c4c4deb99d75c'),
#    'numHits': 3,
#    'TF': 0.507,
#    'WTD': 0.008,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_spin-offs',
#    'docObjID': ObjectId('6078bf99afe0307140f78b50'),
#    'numHits': 6,
#    'TF': 0.505,
#    'WTD': 0.005,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_hieroglyphs',
#    'docObjID': ObjectId('6078bfcdd511816771f645ee'),
#    'numHits': 2,
#    'TF': 0.501,
#    'WTD': 0.001,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_finite_simple_groups',
#    'docObjID': ObjectId('6078bf9bafe0307140f78b57'),
#    'numHits': 2,
#    'TF': 0.502,
#    'WTD': 0.002,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_strikes',
#    'docObjID': ObjectId('6078bfcad511816771f645e6'),
#    'numHits': 1,
#    'TF': 0.501,
#    'WTD': 0.001,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_association_footballers_who_died_while_playing',
#    'docObjID': ObjectId('6078bfc8d511816771f645e1'),
#    'numHits': 7,
#    'TF': 0.504,
#    'WTD': 0.006,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_mathematical_symbols',
#    'docObjID': ObjectId('6078bf9bafe0307140f78b56'),
#    'numHits': 14,
#    'TF': 0.518,
#    'WTD': 0.017,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Village_pump_(proposals)/Archive_129',
#    'docObjID': ObjectId('6078c0613cbcc92a995a4381'),
#    'numHits': 31,
#    'TF': 0.511,
#    'WTD': 0.009,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Criteria_for_speedy_deletion',
#    'docObjID': ObjectId('6078c0653cbcc92a995a438b'),
#    'numHits': 3,
#    'TF': 0.503,
#    'WTD': 0.002,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Manual_of_Style/Lead_section',
#    'docObjID': ObjectId('6078c086e147ca541fa9426b'),
#    'numHits': 1,
#    'TF': 0.502,
#    'WTD': 0.002,
#    'inTitle': False},
#   {'docURL': 'https://phabricator.wikimedia.org:443/T20483',
#    'docObjID': ObjectId('6078c05e3cbcc92a995a4375'),
#    'numHits': 6,
#    'TF': 0.52,
#    'WTD': 0.018,
#    'inTitle': False},
#   {'docURL': 'https://foundation.wikimedia.org:443/wiki/Terms_of_Use',
#    'docObjID': ObjectId('6078c088e147ca541fa9426f'),
#    'numHits': 4,
#    'TF': 0.505,
#    'WTD': 0.007,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Category:Wikipedia_semi-protected_project_pages',
#    'docObjID': ObjectId('6078c089e147ca541fa94272'),
#    'numHits': 4,
#    'TF': 0.508,
#    'WTD': 0.008,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Special:Diff/740835205',
#    'docObjID': ObjectId('6078c0623cbcc92a995a4382'),
#    'numHits': 4,
#    'TF': 0.507,
#    'WTD': 0.007,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Administrators%27_guide/Protecting',
#    'docObjID': ObjectId('6078c0633cbcc92a995a4385'),
#    'numHits': 1,
#    'TF': 0.504,
#    'WTD': 0.004,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia_talk:Protection_policy',
#    'docObjID': ObjectId('6078c089e147ca541fa94273'),
#    'numHits': 3,
#    'TF': 0.523,
#    'WTD': 0.023,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Userboxes',
#    'docObjID': ObjectId('6078c087e147ca541fa9426d'),
#    'numHits': 2,
#    'TF': 0.507,
#    'WTD': 0.005,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Civility',
#    'docObjID': ObjectId('6078c0643cbcc92a995a4388'),
#    'numHits': 4,
#    'TF': 0.51,
#    'WTD': 0.011,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Disruptive_editing',
#    'docObjID': ObjectId('6078c0653cbcc92a995a438a'),
#    'numHits': 2,
#    'TF': 0.508,
#    'WTD': 0.008,
#    'inTitle': False},
#   {'docURL': 'https://meta.wikimedia.org:443/wiki/Protected_pages_considered_harmful',
#    'docObjID': ObjectId('6078c0613cbcc92a995a4380'),
#    'numHits': 1,
#    'TF': 0.52,
#    'WTD': 0.017,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Template:Pp-move',
#    'docObjID': ObjectId('6078c0603cbcc92a995a437e'),
#    'numHits': 1,
#    'TF': 0.51,
#    'WTD': 0.008,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Template:Redirect_category_shell',
#    'docObjID': ObjectId('6078c0613cbcc92a995a437f'),
#    'numHits': 7,
#    'TF': 0.506,
#    'WTD': 0.007,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Be_bold',
#    'docObjID': ObjectId('6078c083e147ca541fa94266'),
#    'numHits': 2,
#    'TF': 0.51,
#    'WTD': 0.01,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Community_portal',
#    'docObjID': ObjectId('6078c08de147ca541fa9428b'),
#    'numHits': 15,
#    'TF': 0.534,
#    'WTD': 0.033,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Hatnote',
#    'docObjID': ObjectId('6078c083e147ca541fa94269'),
#    'numHits': 3,
#    'TF': 0.504,
#    'WTD': 0.003,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Editnotice',
#    'docObjID': ObjectId('6078c0603cbcc92a995a437d'),
#    'numHits': 4,
#    'TF': 0.515,
#    'WTD': 0.012,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/German_Wikipedia',
#    'docObjID': ObjectId('6078c05f3cbcc92a995a4377'),
#    'numHits': 2,
#    'TF': 0.503,
#    'WTD': 0.003,
#    'inTitle': False},
#   {'docURL': 'https://www.mediawiki.org:443/wiki/WMF_product_development_process/2015-11-05',
#    'docObjID': ObjectId('6078c05f3cbcc92a995a437a'),
#    'numHits': 2,
#    'TF': 0.517,
#    'WTD': 0.015,
#    'inTitle': False},
#   {'docURL': 'https://fa.wikipedia.org:443/wiki/%D8%AF%D8%B1%DA%AF%D8%A7%D9%87:%D8%AF%D8%B1%D9%88%D9%86%D9%85%D8%A7%DB%8C%D9%87/%D9%81%D9%87%D8%B1%D8%B3%D8%AA%E2%80%8C%D9%87%D8%A7',
#    'docObjID': ObjectId('6078c0523cbcc92a995a433b'),
#    'numHits': 1,
#    'TF': 0.501,
#    'WTD': 0.001,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_national_anthems',
#    'docObjID': ObjectId('6078c0353cbcc92a995a42e9'),
#    'numHits': 14,
#    'TF': 0.504,
#    'WTD': 0.007,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Spoken_articles',
#    'docObjID': ObjectId('6078c04c3cbcc92a995a4320'),
#    'numHits': 2,
#    'TF': 0.503,
#    'WTD': 0.004,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:File_Upload_Wizard',
#    'docObjID': ObjectId('6078c0503cbcc92a995a4329'),
#    'numHits': 8,
#    'TF': 0.514,
#    'WTD': 0.016,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Edit_requests',
#    'docObjID': ObjectId('6078c05e3cbcc92a995a4371'),
#    'numHits': 1,
#    'TF': 0.504,
#    'WTD': 0.003,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Transclusion',
#    'docObjID': ObjectId('6078c05c3cbcc92a995a436b'),
#    'numHits': 13,
#    'TF': 0.526,
#    'WTD': 0.021,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Cascading_style_sheets',
#    'docObjID': ObjectId('6078c05c3cbcc92a995a4367'),
#    'numHits': 1,
#    'TF': 0.503,
#    'WTD': 0.003,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Reviewing_pending_changes',
#    'docObjID': ObjectId('6078c05a3cbcc92a995a4362'),
#    'numHits': 1,
#    'TF': 0.504,
#    'WTD': 0.004,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_operating_systems',
#    'docObjID': ObjectId('6078c03e3cbcc92a995a42f9'),
#    'numHits': 1,
#    'TF': 0.501,
#    'WTD': 0.001,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Category:Articles_using_small_message_boxes',
#    'docObjID': ObjectId('6078c04f3cbcc92a995a4325'),
#    'numHits': 1,
#    'TF': 0.512,
#    'WTD': 0.009,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/ISO_8859-3',
#    'docObjID': ObjectId('6078c0403cbcc92a995a42ff'),
#    'numHits': 1,
#    'TF': 0.505,
#    'WTD': 0.006,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:RFED',
#    'docObjID': ObjectId('6078c0593cbcc92a995a435e'),
#    'numHits': 1,
#    'TF': 0.505,
#    'WTD': 0.004,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Requests_for_page_protection',
#    'docObjID': ObjectId('6078c0543cbcc92a995a4351'),
#    'numHits': 1,
#    'TF': 0.505,
#    'WTD': 0.004,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_automobile_manufacturers',
#    'docObjID': ObjectId('6078c0463cbcc92a995a4314'),
#    'numHits': 1,
#    'TF': 0.504,
#    'WTD': 0.004,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_solar_thermal_power_stations',
#    'docObjID': ObjectId('6078c03c3cbcc92a995a42f6'),
#    'numHits': 1,
#    'TF': 0.501,
#    'WTD': 0.001,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:Blocking_policy',
#    'docObjID': ObjectId('6078c0553cbcc92a995a4354'),
#    'numHits': 1,
#    'TF': 0.501,
#    'WTD': 0.001,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_memory_biases',
#    'docObjID': ObjectId('6078c0383cbcc92a995a42ec'),
#    'numHits': 1,
#    'TF': 0.506,
#    'WTD': 0.005,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia:LUA',
#    'docObjID': ObjectId('6078c05e3cbcc92a995a4370'),
#    'numHits': 8,
#    'TF': 0.54,
#    'WTD': 0.034,
#    'inTitle': False},
#   {'docURL': 'https://sq.wikipedia.org:443/wiki/Portal:P%C3%ABrmbajtja/Lista_e_temave',
#    'docObjID': ObjectId('6078c0533cbcc92a995a4343'),
#    'numHits': 1,
#    'TF': 0.531,
#    'WTD': 0.031,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/Wikipedia_talk:Cascade-protected_items',
#    'docObjID': ObjectId('6078c05e3cbcc92a995a4372'),
#    'numHits': 20,
#    'TF': 0.567,
#    'WTD': 0.052,
#    'inTitle': False},
#   {'docURL': 'https://foundation.wikimedia.org:443/wiki/Cookie_statement',
#    'docObjID': ObjectId('6078c0543cbcc92a995a4350'),
#    'numHits': 1,
#    'TF': 0.508,
#    'WTD': 0.008,
#    'inTitle': False},
#   {'docURL': 'https://en.wikipedia.org:443/wiki/List_of_bridges_in_India',
#    'docObjID': ObjectId('6078c0473cbcc92a995a4316'),
#    'numHits': 1,
#    'TF': 0.501,
#    'WTD': 0.001,
#    'inTitle': False}]}

# %%
def query2dict(query):
    query_dict = {}
    tokens = query.split(" ")
    for token in tokens:
        if token not in query_dict.keys():
            query_dict[token] = 1
        else:
            query_dict[token] += 1
    return query_dict
query2dict("I love")
# Out:
# {'I': 1, 'love': 1}

# %%
import json
with open("14541.json", 'w') as f_out:
    entities = []
    with open("20180730.txt") as file:
        lines = file.readlines()
        for line in lines:
            ent = line.split(" ")[0][1:-1]
            if ent != "14541":
                entities.append(ent)
    json.dump(entities, f_out)

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb+srv://chris:555Project2021@cluster0.kphap.mongodb.net/SearchEngine?retryWrites=true&w=majority")
mydb = myclient["SearchEngine"]
mycol = mydb["documents"]
mycol.find({'url':"https://en.wikipedia.org:443/wiki/Wikipedia:Contents/Lists"})[0]['title']
# Out:
# 'Wikipedia:Contents/Lists - Wikipedia'

# %%
mydb.keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e5e31e3112e0> in <module>
# ----> 1 mydb.keys()
#
# ~/miniconda3/envs/EMNLP_env/lib/python3.8/site-packages/pymongo/collection.py in __call__(self, *args, **kwargs)
#    3438         """
#    3439         if "." not in self.__name:
# -> 3440             raise TypeError("'Collection' object is not callable. If you "
#    3441                             "meant to call the '%s' method on a 'Database' "
#    3442                             "object it is failing because no such method "
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'keys' method on a 'Database' object it is failing because no such method exists.

# %%
import urllib.request

fp = urllib.request.urlopen("https://en.wikipedia.org/wiki/Timeline_of_musical_events")
mybytes = fp.read()

mystr = mybytes.decode("utf8")
fp.close()

loc = mystr.find("Schubert")
print(mystr[loc-50:loc+50])
# Out:
# d)" title="EMF (band)">EMF</a> (<i><a href="/wiki/Schubert_Dip" title="Schubert Dip">Schubert Dip</a

# %%
import bs4
import urllib.request
url = "https://en.wikipedia.org/wiki/Timeline_of_musical_events"

html = urllib.request.urlopen(url).read()

soup = bs4.BeautifulSoup(html)


for script in soup(["script", "style"]):

    script.decompose()



strips = list(soup.stripped_strings)

# %%
soup.title.string
# Out:
# 'Timeline of musical events - Wikipedia'

# %%
mystr = ' '.join(strips)
loc = mystr.find("Schubert")
print(mystr[loc-50:loc+50])
# Out:
# r ( Leisure ) Cypress Hill ( Cypress Hill ) EMF ( Schubert Dip ) The Infectious Grooves ( The Plague

# %%
stop_words = []
with open('stop_words_en.txt') as f:
    lines = f.readlines()
    for line in lines:
        stop_words.append(line[0:-1])

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'see']
